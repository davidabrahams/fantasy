# %%
import pandas as pd
import os
import sys
from math import floor
import pylev
import re

# %%
curr_dir = os.path.abspath(os.path.dirname("__file__"))

# %%
def get_fp_val(row, values):
#     print(row)
#     return 0
    if (row.Fantasypros_rank >= len(values)):
        return values.iloc[-1]
    rd = int(floor(row.Fantasypros_rank))
    diff = row.Fantasypros_rank - rd
    top_val = values.iloc[rd - 1]
    bot_val = values.iloc[rd]
    return (1 - diff) * top_val + diff * bot_val

def get_bonuses(row, bonuses):
    pos = row['Position'].lower()
    rank = row['Position_rank']
    bonus = bonuses[pos + '12'].iloc[0] - bonuses[pos + '10'].iloc[0]
    return bonus

def get_val_diff(row, df):
    return df.Value.iloc[row.name] - df.Value.iloc[min(row.my_pick - 1, len(df) - 1)]
    
def get_my_pick(e, buff=0):
    my_picks = [9, 16]
    for i in range(15):
        my_picks.append(my_picks[i] + 24)
    for i, m in enumerate(my_picks):
        if m > e-buff:
            return my_picks[max(i - 1, 0)]
        
def round_target(p):
    np.isnan(p):
        return p
    return int((p-1) / 12) + 1
        
def get_name(s):
    i = s.index('.')
    return s[i+2:]

def espn_rank(name, espn):
    names = espn.Name.tolist()
    name_match = min(names, key=lambda x: pylev.levenshtein(x.lower(), name.lower()))
    i = names.index(name_match)
    return i + 1

def get_pos_rank(pos):
    d = {}
    l = []
    for p in pos:
        if p not in d:
            d[p] = 1
        l.append(d[p])
        d[p] += 1
    return l

# %%
fp = pd.read_csv(os.path.join(curr_dir, "FantasyPros_2016_Draft_Overall_Rankings.csv"))

# %%
regex = re.compile('[^a-zA-Z]')
#First parameter is the replacement, second parameter is your input string
re.compile('[^a-zA-Z]').sub('', 'ab3d*E')
fp['Position_alpha'] = fp['Position '].apply(lambda s: re.compile('[^a-zA-Z]').sub('', s))
fp.to_csv('fantasypros.csv')

# %%
using_fp = ''
df = pd.read_csv(os.path.join(curr_dir, "fantasy_rankings.csv"))
espn = pd.read_csv(os.path.join(curr_dir, "espn.csv"))
espn['Name'] = espn['RANK, PLAYER'].apply(get_name)
df['espn_rank'] = df['Player' + using_fp].apply(lambda x: espn_rank(x, espn))
df['my_pick'] = df.espn_rank.apply(get_my_pick)
df['round_target'] = df['my_pick'].apply(round_target)
# df['pos_rank'] = get_pos_rank(df['Pos' + using_fp])
# df['pos_rank_str'] = [p + str(r) for p, r in zip(df['Pos' + using_fp], df.pos_rank)]
# df['diff'] = df.index - df.espn_rank + 1
# df['val_diff'] = df.apply(lambda x: get_val_diff(x, df), axis=1)
# df.index = df.index + 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-167cd13f7e84> in <module>()
#       5 df['espn_rank'] = df['Player' + using_fp].apply(lambda x: espn_rank(x, espn))
#       6 df['my_pick'] = df.espn_rank.apply(get_my_pick)
# ----> 7 df['round_target'] = df['my_pick'].apply(round_target)
#       8 # df['pos_rank'] = get_pos_rank(df['Pos' + using_fp])
#       9 # df['pos_rank_str'] = [p + str(r) for p, r in zip(df['Pos' + using_fp], df.pos_rank)]
#
# /Users/abrahams/Repos/fantasy/ENV/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-10-e23d0d2a7c30> in round_target(p)
#      28
#      29 def round_target(p):
# ---> 30     return int((p-1) / 12) + 1
#      31
#      32 def get_name(s):
#
# ValueError: cannot convert float NaN to integer

# %%
df

# %%
df[(df['Pos' + using_fp] == 'WR') & (df.index<120)].sort_values('val_diff', ascending=False)[['Player' + using_fp, 'espn_rank', 'pos_rank_str', 'my_pick', 'val_diff']]
# Out:
#                 Player  espn_rank pos_rank_str  my_pick  val_diff
# 2        Antonio Brown          1          WR1        9     1.128
# 95     Travis Benjamin        113         WR42      112     0.525
# 5    Odell Beckham Jr.          2          WR2        9     0.367
# 70       Tyler Lockett         83         WR31       81     0.367
# 71         Allen Hurns         81         WR32       81     0.316
# 6          Julio Jones          4          WR3        9     0.252
# 65          John Brown         70         WR29       64    -0.012
# 113      Corey Coleman        112         WR47      112    -0.014
# 68     Jordan Matthews         71         WR30       64    -0.123
# 35         T.Y. Hilton         36         WR14       33    -0.169
# 86    Michael Crabtree         82         WR37       81    -0.259
# 87    Sterling Shepard         85         WR38       81    -0.267
# 119        Kamar Aiken        120         WR49      112    -0.305
# 93        Willie Snead         98         WR40       88    -0.478
# 94         Josh Gordon         97         WR41       88    -0.479
# 48        Randall Cobb         43         WR18       40    -0.635
# 50       Jeremy Maclin         42         WR19       40    -0.708
# 83        Marvin Jones         80         WR35       64    -0.724
# 100       Tavon Austin        101         WR43       88    -0.728
# 92         Kevin White         84         WR39       81    -0.771
# 85      DeSean Jackson         72         WR36       64    -0.785
# 23    Brandon Marshall         19          WR8       16    -0.969
# 108    Vincent Jackson         99         WR46       88    -1.032
# 53         Eric Decker         44         WR21       40    -1.034
# 24        Jordy Nelson         17          WR9       16    -1.091
# 57      Donte Moncrief         47         WR23       40    -1.120
# 114     Devin Funchess         96         WR48       88    -1.125
# 59    Larry Fitzgerald         54         WR24       40    -1.161
# 105       Stefon Diggs         87         WR44       81    -1.190
# 26          Mike Evans         23         WR10       16    -1.220
# 52       Jarvis Landry         39         WR20       33    -1.233
# 106       Torrey Smith         86         WR45       81    -1.234
# 61       Michael Floyd         52         WR25       40    -1.296
# 62     Kelvin Benjamin         46         WR26       40    -1.300
# 63         Golden Tate         45         WR27       40    -1.309
# 15          A.J. Green         13          WR4        9    -1.345
# 55        Doug Baldwin         38         WR22       33    -1.349
# 28      Alshon Jeffery         21         WR11       16    -1.373
# 17     DeAndre Hopkins          7          WR5        9    -1.600
# 31        Amari Cooper         29         WR12       16    -1.612
# 33       Brandin Cooks         26         WR13       16    -1.696
# 18          Dez Bryant         10          WR6        9    -1.778
# 64      Julian Edelman         37         WR28       33    -1.808
# 78      Devante Parker         53         WR33       40    -1.837
# 38        Keenan Allen         31         WR15       16    -1.901
# 39       Sammy Watkins         24         WR16       16    -1.913
# 40    Demaryius Thomas         30         WR17       16    -1.984
# 79    Emmanuel Sanders         51         WR34       40    -1.986
# 20      Allen Robinson         15          WR7        9    -2.012

# %%
df = pd.read_csv(os.path.join(curr_dir, "fantasy_rankings.csv"))
bonuses = pd.read_csv(os.path.join(curr_dir, "bonuses.csv"))
espn = pd.read_csv(os.path.join(curr_dir, "espn.csv"))
df = df[pd.notnull(df.Value)].iloc[:100]

df['Fantasypros_value'] = df.apply(lambda x: get_fp_val(x, df.Value), axis=1)
df['Position_rank'] = df.Position.apply(lambda x: int(x[2:]))
df.Position = df.Position.apply(lambda x: x[:2])
df['Bonus_adj'] = df.apply(lambda x: get_bonuses(x, bonuses), axis=1) + df.Fantasypros_value
df = df.sort_values('Bonus_adj', ascending=False).reset_index(drop=True)
espn['Name'] = espn['RANK, PLAYER'].apply(get_name)
df['espn_rank'] = df['Fantasypros_name'].apply(lambda x: espn_rank(x, espn))

# %%
def get_trade_values(df, picks):
    picks = [p - 1 for p in picks]
    return df.iloc[picks].Bonus_adj.mean()

# %%
get_trade_values(df, [7, 18, 42,66, 90])

# %%
get_trade_values(df, [9, 16, 40, 64, 88])
get_trade_values(df, [9, 16, 40, 64, 88])

# %%
df.to_csv('my_ranks.csv')

# %%
df[['Fantasypros_name', 'Fantasypros_rank', 'espn_rank']].iloc[40:]

# %%
df.iloc[50:]
